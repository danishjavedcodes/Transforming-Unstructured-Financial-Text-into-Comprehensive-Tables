# %% [markdown]
# <a href="https://www.kaggle.com/code/danishjavedcodes/unstructured-financial-text-into-tables?scriptVersionId=162889571" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/financial-raw-data/data.txt

# %% [markdown]
# **Importing Dependencies**

# %%
import pandas as pd
import re
import pandas as pd
import re
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tag import pos_tag
import spacy
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# **Reading Data from file**

# %%
import pandas as pd

# Load the text data from the file
with open('/kaggle/input/financial-raw-data/data.txt', 'r') as file:
    text_data = file.read()

# %% [markdown]
# **Converting to Data frame**

# %%
# Split the text into Title and details
data = [title.split(":", 1) for title in text_data.split("\n") if title]

# Create a dataframe~
df = pd.DataFrame(data, columns=["Title", "Details"])
df
# Out:
#                        Title  \
# 0     Real Estate Investment
# 1       Stock Market Trading
# 2   Car Purchase Negotiation
# 3  Cryptocurrency Investment
# 4         Antique Collection
# 5   Foreign Exchange Trading
# 6             Art Investment
# 7  Commodity Futures Trading
# 8  Startup Equity Investment
# 9    Precious Metals Trading
#
#                                              Details
# 0   John is considering buying a rental property ...
# 1   Emily monitors the stock market daily, lookin...
# 2   Sarah visits a local car dealership to buy a ...
# 3   David follows the cryptocurrency market close...
# 4   Rebecca is passionate about antiques and regu...
# 5   James is a forex trader who specializes in cu...
# 6   Michael attends an art auction featuring work...
# 7   Lisa trades commodity futures contracts and n...
# 8   Tom is approached by a startup seeking fundin...
# 9   Jessica diversifies her investment portfolio ...

# %% [markdown]
# **Tokanizing Descriptions**

# %%
df = pd.DataFrame(data, columns=["Title", "Details"])
# Tokenize the details
tokenized_details = df['Details'].apply(lambda x: sent_tokenize(x))
df['Tokenized Details'] = tokenized_details

# %% [markdown]
# **Functions for Data Extractions**

# %%
def find_proper_nouns(text):
    tokens = word_tokenize(text)
    tagged_words = pos_tag(tokens)
    proper_nouns = [word for word, pos in tagged_words if pos == 'NNP' or pos == 'NNPS']
    
    return proper_nouns

def find_actions(text):
    doc = nlp(text)
    actions = [token.text for token in doc if token.pos_ == 'VERB' or token.pos_ == 'VB']
    return actions

def find_prices(text):
    # Regular expression to match common price patterns
    price_pattern = re.compile(r'\$\s?\d+(?:,\d{3})*(?:\.\d{1,2})?|\d+(?:,\d{3})*(?:\.\d{1,2})?\s?USD|\d+(?:,\d{3})*(?:\.\d{1,2})?\s?dollars')
    # Find all matches in the text
    matches = re.finditer(price_pattern, text)
    # Extract and return the matched prices
    prices = [match.group(0) for match in matches]   
    return prices

def find_product_types(text):
    tokens = word_tokenize(text)
    tagged_words = pos_tag(tokens)
    
    # Define POS patterns for identifying potential product types
    product_type_patterns = [
        ('NN', 'NNS'),    # Singular and plural nouns
    ]
    
    # Find words matching the specified POS patterns
    product_types = [word for word, pos in tagged_words if any((pos == pos1 or pos == pos2) for pos1, pos2 in product_type_patterns)]
    return product_types

def find_product_conditions(text):
    tokens = word_tokenize(text)
    tagged_words = pos_tag(tokens)  
    # Define POS patterns for identifying potential product conditions
    condition_patterns = [
        ('JJ',),          # Adjectives
        ('RB', 'JJ'),      # Adverbs + adjectives
    ]
    # Find words matching the specified POS patterns
    product_conditions = [word for word, pos in tagged_words if any(all((pos == p) for p in pattern) for pattern in condition_patterns)]
    return product_conditions

# %% [markdown]
# **Generating new Detailed Data Frame Table**

# %%
new_df = pd.DataFrame(columns=["Title", "Person", "Product", "Condition", "Actions", "Price"])

# %%
# Extracting information from tokanized details
title = ""
for index, row in df.iterrows():
    new_title = row['Title']
    for sentence in row['Tokenized Details']:
        Person = " ,".join(find_proper_nouns(sentence))
        Product = " ,".join(find_product_types(sentence))
        Condition = " ,".join(find_product_conditions(sentence))
        Action = " ,".join(find_actions(sentence))
        Price = " ,".join(find_prices(sentence))
        if new_title != title:
            new_df = pd.concat([new_df, pd.DataFrame({"Title": [new_title], "Person": [Person], "Product": [Product], "Condition": [Condition], "Actions": [Action], "Price": Price})], ignore_index=True)
        else:
            new_df = pd.concat([new_df, pd.DataFrame({"Title": " ", "Person": [Person], "Product": [Product], "Condition": [Condition], "Actions": [Action], "Price": Price})], ignore_index=True)
        title = new_title
new_df
# Out:
#                         Title          Person  \
# 0      Real Estate Investment            John
# 1
# 2
# 3        Stock Market Trading
# 4
# 5
# 6    Car Purchase Negotiation           Sarah
# 7
# 8
# 9
# 10  Cryptocurrency Investment  David ,Bitcoin
# 11                                        BTC
# 12                                    Bitcoin
# 13         Antique Collection         Rebecca
# 14
# 15
# 16   Foreign Exchange Trading           James
# 17                                    USD/EUR
# 18                                         US
# 19             Art Investment         Michael
# 20
# 21                                      Aware
# 22  Commodity Futures Trading            Lisa
# 23
# 24
# 25  Startup Equity Investment             Tom
# 26
# 27                                        Tom
# 28    Precious Metals Trading         Jessica
# 29
# 30
#
#                                               Product  \
# 0                    property ,bustling ,neighborhood
# 1                    listings ,two-bedroom ,apartment
# 2        income ,properties ,area ,purchase ,decision
# 3                stock ,market ,opportunities ,stocks
# 4           shares ,tech ,company ,market ,volatility
# 5   company ,prospects ,shares ,plans ,price ,rebo...
# 6                            car ,dealership ,vehicle
# 7                                       models ,sedan
# 8                                                deal
# 9   knowledge ,car ,pricing ,market ,trends ,sales...
# 10                    cryptocurrency ,market ,decides
# 11               purchases ,price ,coin ,surge ,value
# 12           weeks ,gains ,traction ,holdings ,profit
# 13            antiques ,attends ,auctions ,collection
# 14                            auction ,vintage ,watch
# 15       significance ,resale ,value ,bid ,collection
# 16                            trader ,currency ,pairs
# 17                           exchange ,rate ,tensions
# 18  opportunity ,dollars ,rate ,currency ,apprecia...
# 19                            auction ,works ,artists
# 20                                     painting ,star
# 21  artist ,reputation ,demand ,work ,purchases ,p...
# 22  trades ,commodity ,futures ,contracts ,surge ,...
# 23  purchases ,futures ,contracts ,crude ,oil ,bar...
# 24         price ,barrel ,contracts ,market ,momentum
# 25             startup ,funding ,technology ,platform
# 26    company ,potential ,exchange ,equity ,ownership
# 27  startup ,grows ,investors ,value ,equity ,stak...
# 28                      investment ,portfolio ,metals
# 29  purchases ,bullion ,price ,dips ,ounce ,reboun...
# 30  tensions ,gold ,holdings ,ounce ,market ,volat...
#
#                          Condition  \
# 0                           rental
# 1                    various ,cozy
# 2       potential ,rental ,similar
# 3
# 4                              due
# 5                        long-term
# 6                       local ,new
# 7     test-driving ,several ,sleek
# 8
# 9
# 10
# 11
# 12          following ,significant
# 13           passionate ,regularly
# 14                    recent ,rare
# 15  historical ,potential ,curated
# 16                           forex
# 17               due ,geopolitical
# 18             euros ,advantageous
# 19               art ,contemporary
# 20
# 21                       long-term
# 22                     due ,global
# 23
# 24                          upward
# 25                      innovative
# 26
# 27           additional ,lucrative
# 28                        precious
# 29                        economic
# 30                    geopolitical
#
#                                         Actions     Price
# 0                           considering ,buying
# 1                    researching ,finds ,listed  $200,000
# 2                   evaluates ,compares ,making
# 3                  monitors ,looking ,buy ,sell
# 4                      notices ,eyeing ,dropped
# 5       Believing ,decides ,buy ,sell ,rebounds       $50
# 6                                           buy
# 7                      driving ,settles ,priced   $30,000
# 8                              knows ,negotiate
# 9                       Using ,haggles ,secures   $28,000
# 10                     follows ,decides ,invest
# 11                      purchases ,anticipating   $50,000
# 12                  following ,sells ,realizing   $70,000
# 13                              attends ,expand
# 14                                spots ,listed    $5,000
# 15  Recognizing ,places ,winning ,adds ,curated
# 16                                  specializes
# 17                        observes ,fluctuating
# 18         Sensing ,sells ,buys ,aiming ,profit
# 19                 attends ,featuring ,emerging
# 20                   identifies ,rising ,priced   $10,000
# 21                  growing ,purchases ,holding
# 22                              trades ,notices
# 23                   purchases ,expecting ,rise       $70
# 24                 reaches ,sells ,capitalizing       $90
# 25                          approached ,seeking
# 26                           Intrigued ,invests   $50,000
# 27                    grows ,attracts ,offering
# 28                         diversifies ,trading
# 29                purchases ,dips ,anticipating    $1,800
# 30                   escalate ,sells ,profiting    $2,200
